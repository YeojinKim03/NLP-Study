# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/NLP Study/NLP_Study/Natural_Language_Processing_with_PyTorch
# Out:
# /content/drive/MyDrive/NLP Study/NLP_Study/Natural_Language_Processing_with_PyTorch

# %%
# !git config --global user.email 'yeojin.r.kim@gmail.com'
# !git config --global user.name 'YeojinKim03'

# %%
# !git add 'C3_NLP_With_Pytorch .ipynb'

# %%
# !git commit -m 'ADD : Upload Summary Notes'
# !git push
# Out:
# [main 9d222ea] ADD : Upload Summary Notes
#  4 files changed, 2 insertions(+), 1 deletion(-)
#  rename {Natural Language Processing with PyTorch => Natural_Language_Processing_with_PyTorch}/C1_NLP_With_Pytorch .ipynb (100%)
#  rename {Natural Language Processing with PyTorch => Natural_Language_Processing_with_PyTorch}/C2_NLP_With_Pytorch .ipynb (100%)
#  rename {Natural Language Processing with PyTorch => Natural_Language_Processing_with_PyTorch}/C3_NLP_With_Pytorch .ipynb (99%)
#  create mode 100644 Natural_Language_Processing_with_PyTorch/upload_code.ipynb
# Enumerating objects: 8, done.
# Counting objects: 100% (8/8), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (7/7), done.
# Writing objects: 100% (7/7), 737.39 KiB | 5.46 MiB/s, done.
# Total 7 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/YeojinKim03/NLP_Study.git
#    56cbccc..9d222ea  main -> main
